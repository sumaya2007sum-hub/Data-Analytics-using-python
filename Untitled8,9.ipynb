# %% [markdown]
# <a href="https://colab.research.google.com/github/sumaya2007sum-hub/Data-Analytics-using-python/blob/main/Untitled8%2C9.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import matplotlib.pyplot as plt

marks = [45,50,55,60,70,72,75,80,90,95]

plt.hist(marks, bins=5)

plt.title("Students Marks Distribution")

plt.xlabel("Marks")

plt.ylabel("Number of Students")

plt.show()

# %%
import matplotlib.pyplot as plt

expenses = [1200, 1500,1800,2000,2500]

plt.hist(expenses,bins=12)

plt.title("Monthly Expense Distribution")
plt.xlabel("Expense Amount")
plt.ylabel("Frequency")

plt.show()

# %%
import matplotlib.pyplot as plt
expenses=[5000,3000,2000]
categories=["Food","Travel","Shopping"]
plt.pie (expenses, labels=categories, autopct="%1.1f%%")
plt.show()
