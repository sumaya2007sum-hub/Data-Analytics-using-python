# %% [markdown]
# <a href="https://colab.research.google.com/github/sumaya2007sum-hub/Data-Analytics-using-python/blob/main/Untitled3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
try:
  num = int (input("Enter Number:"))
  print(num)
except:
  print("Invalid Input")
# Out:
# Enter Number:321
# 321

# %%
def calculate_average(x,y,z):
  return(x+y+z)/3
try:
  x = int(input("Enter first number:"))
  y = int(input(""))
