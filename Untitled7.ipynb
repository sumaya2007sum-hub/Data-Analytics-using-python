# %% [markdown]
# <a href="https://colab.research.google.com/github/sumaya2007sum-hub/Data-Analytics-using-python/blob/main/Untitled7.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
data=pd.Series([10,20,30,50,70])
print(data)
# Out:
# 0    10
# 1    20
# 2    30
# 3    50
# 4    70
# dtype: int64

# %%
import numpy as np

marks=np.array([70,80,90,40])

average=np.mean(marks)

print(average)
# Out:
# 70.0

# %%
import numpy as np
marks=np.array([89,96,78,92])
print(marks[1:3])
# Out:
# [96 78]
