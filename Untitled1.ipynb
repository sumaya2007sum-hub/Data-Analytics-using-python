# %% [markdown]
# <a href="https://colab.research.google.com/github/sumaya2007sum-hub/Data-Analytics-using-python/blob/main/Untitled1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
mark1 = int(input("Enter marks for subject 1:"))
mark2 = int(input("Enter marks for subject 2:"))
mark3 = int(input("Enter marks for subject 3:"))

total = mark1 + mark2 + mark3
Average = total/3

print("Total marks =",total)
print("Average marks =",Average)

if Average >= 50:
  print("pass")
else:
  print("Fail")
# Out:
# Enter marks for subject 1:92
# Enter marks for subject 2:79
# Enter marks for subject 3:88
# Total marks = 259
# Average marks = 86.33333333333333
# pass
