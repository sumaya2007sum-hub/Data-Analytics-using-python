# %% [markdown]
# <a href="https://colab.research.google.com/github/sumaya2007sum-hub/Data-Analytics-using-python/blob/main/Mini_project_pynb.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import files
from google.colab import files
import pandas as pd
import matplotlib.pyplot as plt
data = {
    "order_id": ["OD1001", "OD1002", "OD1003", "OD1004", "OD1005", "OD1006", "OD1007", "OD1008", "OD1009", "OD11010"],
    "order_date": ["2025-01-05", "2025-01-07", "2025-01-08", "2025-01-09", "2025-01-09", "2025-02-02", "2025-02-01", "2025-02-12", "2025-02-15", "2025-02-16"],
    "product_name": ["Blender", "Air fryer", "Study desk", "Yoga Mat", "Mobile phone", "Smart watch", "Fan", "Gaming chair", "Oppo", "iphone 15"],
    "category": ["Apparel", "Electronics", "Furniture", "Apparel", "Furniture", "Apparel", "Home appliances", "Apparel", "Apparel", "Furniture"],
    "quantity_ordered": [1, 2, 1, 1, 6, 5, 1, 4, 3, 10],
    "unit_price": [800, 75, 120, 50, 150, 180, 1000, 110, 200, 90],
    "total_amount": [800, 150, 120, 250, 150, 150, 180, 1000, 460, 240],
    "region": ["North", "South", "East", "West", "South", "North", "East", "West", "South","North"],
}
df = pd.DataFrame(data)
print(df)
# Out:
#   order_id  order_date  product_name         category  quantity_ordered  \
# 0   OD1001  2025-01-05       Blender          Apparel                 1
# 1   OD1002  2025-01-07     Air fryer      Electronics                 2
# 2   OD1003  2025-01-08    Study desk        Furniture                 1
# 3   OD1004  2025-01-09      Yoga Mat          Apparel                 1
# 4   OD1005  2025-01-09  Mobile phone        Furniture                 6
# 5   OD1006  2025-02-02   Smart watch          Apparel                 5
# 6   OD1007  2025-02-01           Fan  Home appliances                 1
# 7   OD1008  2025-02-12  Gaming chair          Apparel                 4
# 8   OD1009  2025-02-15          Oppo          Apparel                 3
# 9  OD11010  2025-02-16     iphone 15        Furniture                10
#
#    unit_price  total_amount region
# 0         800           800  North
# 1          75           150  South
# 2         120           120   East
# ...

# %%
df.head(20)
# Out:
#   order_id  order_date  product_name         category  quantity_ordered  \
# 0   OD1001  2025-01-05       Blender          Apparel                 1
# 1   OD1002  2025-01-07     Air fryer      Electronics                 2
# 2   OD1003  2025-01-08    Study desk        Furniture                 1
# 3   OD1004  2025-01-09      Yoga Mat          Apparel                 1
# 4   OD1005  2025-01-09  Mobile phone        Furniture                 6
# 5   OD1006  2025-02-02   Smart watch          Apparel                 5
# 6   OD1007  2025-02-01           Fan  Home appliances                 1
# 7   OD1008  2025-02-12  Gaming chair          Apparel                 4
# 8   OD1009  2025-02-15          Oppo          Apparel                 3
# 9  OD11010  2025-02-16     iphone 15        Furniture                10
#
#    unit_price  total_amount region
# 0         800           800  North
# 1          75           150  South
# 2         120           120   East
# ...
